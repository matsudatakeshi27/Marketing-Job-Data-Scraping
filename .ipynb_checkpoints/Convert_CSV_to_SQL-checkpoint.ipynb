# %%
pip install mysql.connector
# Out:
# Collecting mysql.connector
#   Downloading mysql-connector-2.2.9.tar.gz (11.9 MB)
#      ---------------------------------------- 11.9/11.9 MB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: mysql.connector
#   Building wheel for mysql.connector (setup.py): started
#   Building wheel for mysql.connector (setup.py): finished with status 'done'
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp38-cp38-win_amd64.whl size=247946 sha256=a1dd179023b1cd7f3d16da56a182562ae2e5c00f2d42954e96ae1dd6362be5e3
#   Stored in directory: c:\users\votri\appdata\local\pip\cache\wheels\57\e4\98\5feafb5c393dd2540e44b064a6f95832990d543e5b4f53ea8f
# Successfully built mysql.connector
# Installing collected packages: mysql.connector
# Note: you may need to restart the kernel to use updated packages.Successfully installed mysql.connector-2.2.9
# [notice] A new release of pip is available: 23.0 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import mysql.connector

# %%
data = pd.read_csv("linkedin-jobs.csv")
data
# Out:
#                                             Title  \
# 0            Marketing Communications Coordinator
# 1                                           Title
# 2                             Marketing Assistant
# 3              Assistant, Marketing - Black Music
# 4                            Associate, Marketing
# ..                                            ...
# 990                              Packer (8am-8pm)
# 991               Junior Marketing Representative
# 992                   Human Resources Coordinator
# 993                 Client Service Representative
# 994  Business Development & Marketing Coordinator
#
#                           Company             Location  \
# 0    JCDecaux North America, Inc.         New York, NY
# 1                         Company             Location
# 2        Los Angeles Philharmonic      Los Angeles, CA
# 3              Warner Music Group         New York, NY
# 4                         Grubhub         New York, NY
# ..                            ...                  ...
# 990                        Genpak       Middletown, NY
# 991         New Age Marketing Inc          Belmont, NC
# 992              Brightland Homes          Addison, TX
# 993        Mars Veterinary Health  Fort Lauderdale, FL
# 994           Foley & Lardner LLP        San Diego, CA
#
#                                                  Apply  \
# 0    https://www.linkedin.com/jobs/view/marketing-c...
# 1                                                Apply
# 2    https://www.linkedin.com/jobs/view/marketing-a...
# 3    https://www.linkedin.com/jobs/view/assistant-m...
# 4    https://www.linkedin.com/jobs/view/associate-m...
# ..                                                 ...
# 990  https://www.linkedin.com/jobs/view/packer-8am-...
# 991  https://www.linkedin.com/jobs/view/junior-mark...
# 992  https://www.linkedin.com/jobs/view/human-resou...
# 993  https://www.linkedin.com/jobs/view/client-serv...
# 994  https://www.linkedin.com/jobs/view/business-de...
#
#                                        Job Description        Date  \
# 0    About JCDecauxJCDecaux is the #1 outdoor adver...  2023-06-22
# 1                                      Job Description        Date
# 2    Job DescriptionThe Los Angeles Philharmonic As...  2023-06-23
# 3    Job Description:At Warner Music Group, we’re a...  2023-06-28
# 4    About The OpportunityWe’re all about connectin...  2023-06-21
# ..                                                 ...         ...
# 990                                                NaN         NaN
# 991  Our management team is looking to fill this po...  2023-06-28
# 992                                                NaN         NaN
# 993                                                NaN  2023-06-11
# 994                                                NaN  2023-06-22
#
#                                           Company Link
# 0    https://www.linkedin.com/company/jcdecaux-n.a....
# 1                                         Company Link
# 2    https://www.linkedin.com/company/los-angeles-p...
# 3    https://www.linkedin.com/company/warner-music-...
# 4    https://www.linkedin.com/company/grubhub-seaml...
# ..                                                 ...
# 990  https://www.linkedin.com/company/genpak?trk=pu...
# 991  https://www.linkedin.com/company/new-age-marke...
# 992  https://www.linkedin.com/company/brightlandhom...
# 993  https://www.linkedin.com/company/mars-veterina...
# 994  https://www.linkedin.com/company/foley-&-lardn...
#
# [995 rows x 7 columns]

# %%
data = data.fillna('')

# %%
#Connect to SQL Server
mydb = mysql.connector.connect(
    host = "localhost",
    user = "root",
    password = "",
    database = "job_scraping"
)

cursor = mydb.cursor()

# cursor.execute('''
#                 CREATE TABLE Marketing_Job (
#                     Job_title varchar(200),
#                     Company_name varchar(100),
#                     Location varchar(100),
#                     Apply varchar(300),
#                     Job_description varchar(2000000),
#                     Date varchar(50),
#                     Company_link varchar(300)
#                 )
# ''')

query = "INSERT INTO Marketing_Job (Job_title, Company_name, Location, Apply, Job_description, Date, Company_link) VALUES (%s, %s, %s, %s, %s, %s, %s)"

# Iterate over each row in the DataFrame and insert the values into the table
for _, row in data.iterrows():
    values = (
        row['Title'],
        row['Company'],
        row['Location'],
        row['Apply'],
        row['Job Description'],
        row['Date'],
        row['Company Link']
    )
    cursor.execute(query, values)

# Commit the changes to the database
mydb.commit()

# Close the cursor and database connection
cursor.close()
mydb.close()
# Out:
# c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\mysql\connector\abstracts.py:130: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if group is 'connector_python':
# c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\mysql\connector\abstracts.py:130: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if group is 'connector_python':
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Input In [5], in <module>
#       1 #Connect to SQL Server
# ----> 2 mydb = mysql.connector.connect(
#       3     host = "localhost",
#       4     user = "root",
#       5     password = "",
#       6     database = "job_scraping"
#       7 )
#       9 cursor = mydb.cursor()
#      11 # cursor.execute('''
#      12 #                 CREATE TABLE Marketing_Job (
#      13 #                     Job_title varchar(200),
#    (...)
#      20 #                 )
#      21 # ''')
#
# File c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\mysql\connector\__init__.py:179, in connect(*args, **kwargs)
#     177     return CMySQLConnection(*args, **kwargs)
#     178 else:
# --> 179     return MySQLConnection(*args, **kwargs)
#
# File c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\mysql\connector\connection.py:95, in MySQLConnection.__init__(self, *args, **kwargs)
#      92 self._pool_config_version = None
#      94 if len(kwargs) > 0:
# ---> 95     self.connect(**kwargs)
#
# File c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\mysql\connector\abstracts.py:716, in MySQLConnectionAbstract.connect(self, **kwargs)
#     713     self.config(**kwargs)
#     715 self.disconnect()
# --> 716 self._open_connection()
#     717 self._post_connection()
#
# File c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\mysql\connector\connection.py:208, in MySQLConnection._open_connection(self)
#     206 self._socket.open_connection()
#     207 self._do_handshake()
# --> 208 self._do_auth(self._user, self._password,
#     209               self._database, self._client_flags, self._charset_id,
#     210               self._ssl)
#     211 self.set_converter_class(self._converter_class)
#     212 if self._client_flags & ClientFlag.COMPRESS:
#
# File c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\mysql\connector\connection.py:144, in MySQLConnection._do_auth(self, username, password, database, client_flags, charset, ssl_options)
#     137 packet = self._protocol.make_auth(
#     138     handshake=self._handshake,
#     139     username=username, password=password, database=database,
#     140     charset=charset, client_flags=client_flags,
#     141     ssl_enabled=self._ssl_active,
#     142     auth_plugin=self._auth_plugin)
#     143 self._socket.send(packet)
# --> 144 self._auth_switch_request(username, password)
#     146 if not (client_flags & ClientFlag.CONNECT_WITH_DB) and database:
#     147     self.cmd_init_db(database)
#
# File c:\users\votri\appdata\local\programs\python\python38\lib\site-packages\mysql\connector\connection.py:177, in MySQLConnection._auth_switch_request(self, username, password)
#     175         auth_data = self._protocol.parse_auth_more_data(packet)
#     176 elif packet[4] == 255:
# --> 177     raise errors.get_exception(packet)
#
# ProgrammingError: 1045 (28000): Access denied for user 'root'@'localhost' (using password: NO)
